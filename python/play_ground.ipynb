# %%
print("Hello World")
# Out:
# Hello World

# %%
n, m = 1000, 13

# %%
k = n // m
q = n % m

k,q
# Out:
# (76, 12)

# %%
print("""     /~\\
    ( oo|
    _\\=/_
   /  _  \\
  //|/.\\|\\\\
 ||  \\ /  ||
============
|          |
|          |
|          |""")
# Out:
#      /~\
#     ( oo|
#     _\=/_
#    /  _  \
#   //|/.\|\\
#  ||  \ /  ||
# ...
# |          |
# |          |
# |          |

# %%
print(int(input()) - 2024)
# Out:
# 7
